# %% [markdown]
# ## Estimation using pyPESTO
# In this notebook we reproduce the estimation results of the paper using pyPESTO.
# First just for the parameters on a linear scale.

# %%
import os
import importlib
import pandas as pd

import amici
import amici.plotting
import matplotlib.pyplot as plt
import numpy as np 
import petab 

import pypesto
import pypesto.optimize as optimize
import pypesto.petab
import pypesto.visualize as visualize

# %% [markdown]
# ### Import the PEtab model to pyPESTO and AMICI

# %%
model_name= "Spoegler_conversionReaction"
param_scale= "lin"


# the yaml file includes all important links to other files
yaml_config ="petab/"+param_scale+"/"+model_name+".yaml"
# create a petab problem
petab_problem = petab.Problem.from_yaml(yaml_config)

# import to amici
importer = pypesto.petab.PetabImporter(petab_problem)
importer.compile_model()

model = importer.create_model()

# model properties
print("Model parameters:", list(model.getParameterIds()), "\n")
print("Model constant parameters:", list(model.getFixedParameterIds()), "\n")
print("Model outputs:    ", list(model.getObservableIds()), "\n")
print("Model states:     ", list(model.getStateIds()), "\n")
# Out:
# 2022-05-16 09:50:23.369 - amici.petab_import - INFO - Importing model ...
# 2022-05-16 09:50:23.372 - amici.petab_import - INFO - Model name is 'Sp_gler_ConversionReaction'.
# Writing model code to '/home/vinc777/python_projects/moses/spoegler_model_reduction/amici_models/Sp_gler_ConversionReaction'.
# 2022-05-16 09:50:23.373 - amici.petab_import - INFO - Species: 2
# 2022-05-16 09:50:23.373 - amici.petab_import - INFO - Global parameters: 3
# 2022-05-16 09:50:23.375 - amici.petab_import - INFO - Reactions: 0
# 2022-05-16 09:50:23.384 - amici.petab_import - INFO - Observables: 1
# 2022-05-16 09:50:23.385 - amici.petab_import - INFO - Sigmas: 1
# 2022-05-16 09:50:23.388 - amici.petab_import - DEBUG - Adding output parameters to model: OrderedDict([('noiseParameter1_observed_B', None)])
# 2022-05-16 09:50:23.389 - amici.petab_import - DEBUG - Adding initial assignments for []
# 2022-05-16 09:50:23.390 - amici.petab_import - DEBUG - Condition table: (1, 0)
# 2022-05-16 09:50:23.391 - amici.petab_import - DEBUG - Fixed parameters are []
# 2022-05-16 09:50:23.391 - amici.petab_import - INFO - Overall fixed parameters: 0
# 2022-05-16 09:50:23.393 - amici.petab_import - INFO - Variable parameters: 4
# 2022-05-16 09:50:23.405 - amici.sbml_import - INFO - Finished gathering local SBML symbols       ++ (6.68E-04s)
# 2022-05-16 09:50:23.410 - amici.sbml_import - INFO - Finished processing SBML parameters         ++ (2.07E-04s)
# 2022-05-16 09:50:23.416 - amici.sbml_import - INFO - Finished processing SBML compartments       ++ (2.68E-04s)
# 2022-05-16 09:50:23.430 - amici.sbml_import - INFO - Finished processing SBML species initials  +++ (5.42E-04s)
# 2022-05-16 09:50:23.486 - amici.sbml_import - INFO - Finished processing SBML rate rules        +++ (4.96E-02s)
# 2022-05-16 09:50:23.487 - amici.sbml_import - INFO - Finished processing SBML species            ++ (6.26E-02s)
# 2022-05-16 09:50:23.494 - amici.sbml_import - INFO - Finished processing SBML reactions          ++ (1.57E-04s)
# 2022-05-16 09:50:23.501 - amici.sbml_import - INFO - Finished processing SBML rules              ++ (4.89E-04s)
# 2022-05-16 09:50:23.508 - amici.sbml_import - INFO - Finished processing SBML initial assignments++ (5.61E-05s)
# 2022-05-16 09:50:23.513 - amici.sbml_import - INFO - Finished processing SBML species references ++ (4.59E-04s)
# 2022-05-16 09:50:23.522 - amici.sbml_import - INFO - Finished processing SBML events             ++ (1.64E-04s)
# 2022-05-16 09:50:23.524 - amici.sbml_import - INFO - Finished importing SBML                      + (1.26E-01s)
# 2022-05-16 09:50:23.550 - amici.sbml_import - INFO - Finished processing SBML observables         + (1.85E-02s)
# 2022-05-16 09:50:23.579 - amici.ode_export - INFO - Finished running smart_multiply              ++ (4.11E-05s)
# 2022-05-16 09:50:23.585 - amici.ode_export - INFO - Finished importing SbmlImporter               + (1.08E-02s)
# 2022-05-16 09:50:23.621 - amici.ode_export - INFO - Finished simplifying Jy                    ++++ (1.40E-02s)
# 2022-05-16 09:50:23.623 - amici.ode_export - INFO - Finished computing Jy                       +++ (1.95E-02s)
# 2022-05-16 09:50:23.637 - amici.ode_export - INFO - Finished simplifying y                     ++++ (1.27E-04s)
# 2022-05-16 09:50:23.639 - amici.ode_export - INFO - Finished computing y                        +++ (8.39E-03s)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb Cell 4' in <module>
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb#ch0000003vscode-remote?line=9'>10</a> # import to amici
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb#ch0000003vscode-remote?line=10'>11</a> importer = pypesto.petab.PetabImporter(petab_problem)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb#ch0000003vscode-remote?line=11'>12</a> importer.compile_model()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb#ch0000003vscode-remote?line=13'>14</a> model = importer.create_model()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/vinc777/python_projects/moses/spoegler_model_reduction/estimation_linear.ipynb#ch0000003vscode-remote?line=15'>16</a> # model properties
#
# File ~/.local/lib/python3.8/site-packages/pypesto/petab/importer.py:263, in PetabImporter.compile_model(self, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=259'>260</a> if os.path.exists(self.output_folder):
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=260'>261</a>     shutil.rmtree(self.output_folder)
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=262'>263</a> amici.petab_import.import_model(
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=263'>264</a>     sbml_model=self.petab_problem.sbml_model,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=264'>265</a>     condition_table=self.petab_problem.condition_df,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=265'>266</a>     observable_table=self.petab_problem.observable_df,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=266'>267</a>     model_name=self.model_name,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=267'>268</a>     model_output_dir=self.output_folder,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=268'>269</a>     **kwargs,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/pypesto/petab/importer.py?line=269'>270</a> )
#
# File ~/.local/lib/python3.8/site-packages/amici/logging.py:194, in log_execution_time.<locals>.decorator_timer.<locals>.wrapper_timer(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=190'>191</a>     recursion = '+' * (recursion_level - 1)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=192'>193</a> tstart = time.perf_counter()
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=193'>194</a> rval = func(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=194'>195</a> tend = time.perf_counter()
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=195'>196</a> spacers = ' ' * max(54 - len(description) - len(logger.name) -
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=196'>197</a>                     len(recursion), 0)
#
# File ~/.local/lib/python3.8/site-packages/amici/petab_import.py:579, in import_model_sbml(sbml_model, condition_table, observable_table, measurement_table, model_name, model_output_dir, verbose, allow_reinit_fixpar_initcond, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=573'>574</a> logger.info("Variable parameters: "
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=574'>575</a>             + str(len(sbml_model.getListOfParameters())
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=575'>576</a>                   - len(fixed_parameters)))
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=577'>578</a> # Create Python module from SBML model
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=578'>579</a> sbml_importer.sbml2amici(
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=579'>580</a>     model_name=model_name,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=580'>581</a>     output_dir=model_output_dir,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=581'>582</a>     observables=observables,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=582'>583</a>     constant_parameters=fixed_parameters,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=583'>584</a>     sigmas=sigmas,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=584'>585</a>     allow_reinit_fixpar_initcond=allow_reinit_fixpar_initcond,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=585'>586</a>     noise_distributions=noise_distrs,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=586'>587</a>     verbose=verbose,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=587'>588</a>     **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/petab_import.py?line=589'>590</a> return sbml_importer
#
# File ~/.local/lib/python3.8/site-packages/amici/sbml_import.py:377, in SbmlImporter.sbml2amici(self, model_name, output_dir, observables, constant_parameters, sigmas, noise_distributions, verbose, assume_pow_positivity, compiler, allow_reinit_fixpar_initcond, compile, compute_conservation_laws, simplify, log_as_log10, generate_sensitivity_code, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=364'>365</a> ode_model.import_from_sbml_importer(
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=365'>366</a>     self, compute_cls=compute_conservation_laws)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=366'>367</a> exporter = ODEExporter(
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=367'>368</a>     ode_model,
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=368'>369</a>     model_name=model_name,
#    (...)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=374'>375</a>     generate_sensitivity_code=generate_sensitivity_code
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=375'>376</a> )
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=376'>377</a> exporter.generate_model_code()
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=378'>379</a> if compile:
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/sbml_import.py?line=379'>380</a>     if not has_clibs:
#
# File ~/.local/lib/python3.8/site-packages/amici/logging.py:194, in log_execution_time.<locals>.decorator_timer.<locals>.wrapper_timer(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=190'>191</a>     recursion = '+' * (recursion_level - 1)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=192'>193</a> tstart = time.perf_counter()
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=193'>194</a> rval = func(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=194'>195</a> tend = time.perf_counter()
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=195'>196</a> spacers = ' ' * max(54 - len(description) - len(logger.name) -
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=196'>197</a>                     len(recursion), 0)
#
# File ~/.local/lib/python3.8/site-packages/amici/ode_export.py:2541, in ODEExporter.generate_model_code(self)
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2536'>2537</a> with _monkeypatched(sp.Pow, '_eval_derivative',
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2537'>2538</a>                     _custom_pow_eval_derivative):
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2539'>2540</a>     self._prepare_model_folder()
# -> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2540'>2541</a>     self._generate_c_code()
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2541'>2542</a>     self._generate_m_code()
#
# File ~/.local/lib/python3.8/site-packages/amici/ode_export.py:2576, in ODEExporter._generate_c_code(self)
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2573'>2574</a> if func_info.generate_body:
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2574'>2575</a>     dec = log_execution_time(f'writing {func_name}.cpp', logger)
# -> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2575'>2576</a>     dec(self._write_function_file)(func_name)
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2576'>2577</a> if func_name in sparse_functions and func_info.body:
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2577'>2578</a>     self._write_function_index(func_name, 'colptrs')
#
# File ~/.local/lib/python3.8/site-packages/amici/logging.py:194, in log_execution_time.<locals>.decorator_timer.<locals>.wrapper_timer(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=190'>191</a>     recursion = '+' * (recursion_level - 1)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=192'>193</a> tstart = time.perf_counter()
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=193'>194</a> rval = func(*args, **kwargs)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=194'>195</a> tend = time.perf_counter()
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=195'>196</a> spacers = ' ' * max(54 - len(description) - len(logger.name) -
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/logging.py?line=196'>197</a>                     len(recursion), 0)
#
# File ~/.local/lib/python3.8/site-packages/amici/ode_export.py:2766, in ODEExporter._write_function_file(self, function)
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2763'>2764</a>     iszero = smart_is_zero_matrix(self.model.sparseeq(sym))
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2764'>2765</a> elif sym in self.functions:
# -> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2765'>2766</a>     iszero = smart_is_zero_matrix(self.model.eq(sym))
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2766'>2767</a> else:
#    <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=2767'>2768</a>     iszero = len(self.model.sym(sym)) == 0
#
# File ~/.local/lib/python3.8/site-packages/amici/ode_export.py:846, in smart_is_zero_matrix(x)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=836'>837</a> """A faster implementation of sympy's is_zero_matrix
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=837'>838</a>
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=838'>839</a> Avoids repeated indexer type checks and double iteration to distinguish
#    (...)
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=841'>842</a> :param x: Matrix to check
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=842'>843</a> """
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=844'>845</a> if isinstance(x, sp.MutableDenseMatrix):
# --> <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=845'>846</a>     return all(xx.is_zero is True for xx in x.flat())
#     <a href='file:///home/vinc777/.local/lib/python3.8/site-packages/amici/ode_export.py?line=847'>848</a> return x.nnz() == 0
#
# AttributeError: 'MutableDenseMatrix' object has no attribute 'flat'

# %%
solver = importer.create_solver(model)
model.setTimepoints([0,1,5,10,30,60])

model.setParameterByName("k1", 0.2)
model.setParameterByName("k2", 0.1)
model.setParameterByName("k3", 0)

# Run simulation using default model parameters and solver options
rdata = amici.runAmiciSimulation(model, solver)

# get simulated data
simulations = rdata.x

# plot simulated trajectories
amici.plotting.plotStateTrajectories(rdata)
amici.plotting.plotObservableTrajectories(rdata)

# %% [markdown]
# ### Optimization
# Next we do a simple optimization without using priors.

# %%
# enable sensitivities 
solver.setSensitivityOrder(amici.SensitivityOrder_first)
solver.setSensitivityMethod(amici.SensitivityMethod_forward)
model.requireSensitivitiesForAllParameters()

# create objective function from amici model
objective = importer.create_objective(model, solver)

# %%
print('optimal x = ', petab_problem.x_nominal)
print('optimal lh value', objective(petab_problem.x_nominal))
# Out:
# optimal x =  [0.2, 0.1, 0.0, 0.15]
# optimal lh value -3.418410576784529

# %%
# create optimizer object
optimizer = optimize.ScipyOptimizer(method="L-BFGS-B")

# create problem object
problem = importer.create_problem(objective=objective)

# do the optimization
n_starts= 100
result = optimize.minimize(
        problem=problem, optimizer=optimizer, n_starts=n_starts, filename=None
)
# Out:
# 100%|██████████| 100/100 [00:43<00:00,  2.32it/s]

# %% [markdown]
# #### Results

# %%
# print results
best_result=result.optimize_result.as_list("x")[0]["x"]
print('best parameter: ', best_result)
print('best likelihood value: ', objective(best_result))


# waterfall plot
fvals = result.optimize_result.get_for_key("fval")
visualize.waterfall_lowlevel(fvals, scale_y='lin')
# Out:
# best parameter:  [0.294199   0.05696116 0.00175698 0.09283202]
# best likelihood value:  -5.748130162098678
# <AxesSubplot:title={'center':'Waterfall plot'}, xlabel='Ordered optimizer run', ylabel='Function value'>

# %% [markdown]
# Next we look on the number of converged runs.

# %%
# converged means close to the best result up to a threshold

threshold = 1e-2
n_compares = len(result.optimize_result.as_list("x"))
n_converged = 0
for i in range(0, n_compares):
    compare_result = result.optimize_result.as_list("x")[i]["x"]
    converged = (np.abs((compare_result - best_result)) < (threshold * len(compare_result))).all()
    if converged:
        n_converged += 1

print("Number of converged runs: ", n_converged)
# Out:
# Number of converged runs:  4

# %%
visualize.parameters(result)
# Out:
# <AxesSubplot:title={'center':'Estimated parameters'}, xlabel='Parameter value', ylabel='Parameter'>

# %%
startpoints = result.optimize_result.get_for_key('x0')

# %%
results =   [['theta1',petab_problem.x_nominal[0], best_result[0], 0.2, best_result[0], objective(petab_problem.x_nominal), objective(best_result)],
             ['theta2', petab_problem.x_nominal[1], best_result[1], 0.1, best_result[1], objective(petab_problem.x_nominal), objective(best_result)],
             ['theta3', petab_problem.x_nominal[2], best_result[2], 0.0, best_result[2], objective(petab_problem.x_nominal) , objective(best_result)],
             ['sigma', petab_problem.x_nominal[3], best_result[3], 0.15, best_result[3], objective(petab_problem.x_nominal), objective(best_result)]]

results_df = pd.DataFrame(results, columns=['Parameter', 'Nominal', 'best', 'nominal-linear', 'best-linear', 'nominal-likelihood', 'likelihood'])

print(results_df)

results_df.to_csv("estimation_results/"+param_scale+".csv", index=False)
# Out:
#   Parameter  Nominal      best  nominal-linear  best-linear  \
# 0    theta1     0.20  0.294199            0.20     0.294199
# 1    theta2     0.10  0.056961            0.10     0.056961
# 2    theta3     0.00  0.001757            0.00     0.001757
# 3     sigma     0.15  0.092832            0.15     0.092832
#
#    nominal-likelihood  likelihood
# 0           -3.418411    -5.74813
# 1           -3.418411    -5.74813
# 2           -3.418411    -5.74813
# 3           -3.418411    -5.74813
